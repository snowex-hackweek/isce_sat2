# %%
import numpy as np
import geopandas as gpd
import pickle
import pandas as pd

# %%
out_fp = "../../data/grmesa_20-40.pkl"
df = pickle.load(open(out_fp, 'rb'))

# %%
df.head(2)
# Out:
#                                n_fit_photons  dh_fit_dy   h_sigma  cycle  \
# time
# 2018-10-17 22:31:18.762338460             82        0.0  0.020675      1
# 2018-10-17 22:31:18.765121812             92        0.0  0.017144      1
#
#                                spot  rgt  segment_id  pflags  \
# time
# 2018-10-17 22:31:18.762338460     1  295      216246       0
# 2018-10-17 22:31:18.765121812     1  295      216247       0
#
#                                w_surface_window_final  dh_fit_dx  \
# time
# 2018-10-17 22:31:18.762338460                     3.0   0.025475
# 2018-10-17 22:31:18.765121812                     3.0   0.024812
#
#                                    distance       h_mean  rms_misfit  \
# time
# 2018-10-17 22:31:18.762338460  4.336682e+06  1770.597407    0.185885
# 2018-10-17 22:31:18.765121812  4.336702e+06  1771.111516    0.163035
#
#                                  delta_time  gt                     geometry  \
# time
# ...

# %%
# create date col
df['date'] = df.index.date

# %%
# create lon col
df['lon'] = df.centroid.x
# Out:
# /tmp/ipykernel_890/4086802392.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df.centroid.x
# time
# 2018-10-17 22:31:18.762338460   -108.297284
# 2018-10-17 22:31:18.765121812   -108.297307
# 2018-10-17 22:31:18.767913824   -108.297329
# 2018-10-17 22:31:18.770710484   -108.297351
# 2018-10-17 22:31:18.773512216   -108.297373
#                                     ...
# 2022-03-07 23:39:21.158048752   -108.118135
# 2022-03-07 23:39:21.160135040   -108.081417
# 2022-03-07 23:39:21.162953008   -108.081438
# 2022-03-07 23:39:21.165770800   -108.081459
# 2022-03-07 23:39:21.168588224   -108.081480
# Length: 63541, dtype: float64

# %%
# create lon col
df['lat'] = df.centroid.y
# Out:
# /tmp/ipykernel_890/601729011.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['lat'] = df.centroid.y

# %%
df.head(2)
# Out:
#                                n_fit_photons  dh_fit_dy   h_sigma  cycle  \
# time
# 2018-10-17 22:31:18.762338460             82        0.0  0.020675      1
# 2018-10-17 22:31:18.765121812             92        0.0  0.017144      1
#
#                                spot  rgt  segment_id  pflags  \
# time
# 2018-10-17 22:31:18.762338460     1  295      216246       0
# 2018-10-17 22:31:18.765121812     1  295      216247       0
#
#                                w_surface_window_final  dh_fit_dx  \
# time
# 2018-10-17 22:31:18.762338460                     3.0   0.025475
# 2018-10-17 22:31:18.765121812                     3.0   0.024812
#
#                                    distance       h_mean  rms_misfit  \
# time
# 2018-10-17 22:31:18.762338460  4.336682e+06  1770.597407    0.185885
# 2018-10-17 22:31:18.765121812  4.336702e+06  1771.111516    0.163035
#
#                                  delta_time  gt                     geometry  \
# time
# ...

# %%
df.to_csv(r'icesat_uavsar_grmesa.csv')
