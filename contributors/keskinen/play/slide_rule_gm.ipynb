# %%
from sliderule import icesat2
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
import contextily as cx

# %%
icesat2.init("icesat2sliderule.org", verbose=True)

# %%
grand_mesa = icesat2.toregion('grandmesa.geojson')["poly"]

# %%
res = gpd.GeoDataFrame()
for conf in range(2,5):
    parms = {"poly": grand_mesa,
    "srt": icesat2.SRT_LAND,
    "cnf": [conf],
    "len": 100.0,
    "res": 50.0,
    "maxi": 1,
    "atl08_class":"atl08_ground",
    "t0":'2019-12-10T00:00:00Z',
    "t1":'2020-02-12T00:00:00Z'}

    rsps = icesat2.atl06p(parms)
    rsps['confidence'] = conf
    res = res.append(rsps)
    # # rsps['time'] = rsps.index
    # print(rsps.size)
    # f, ax = plt.subplots()
    # rsps.plot(column = 'h_mean', ax = ax, legend = True)
    # gpd.read_file('grandmesa.geojson').plot(facecolor = "none", edgecolor = 'red', ax = ax)
    # cx.add_basemap(ax, crs=rsps.crs.to_string())
    # plt.show()
# Out:
# INFO:sliderule.icesat2:Identified 6 resources to process
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20191211143520_11560506_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20191213021930_11790502_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200109131121_02110606_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200111005531_02340602_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200207114722_06530606_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200115004711_02950602_005_01.h5 ...
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:processing of ATL03_20200207114722_06530606_005_01.h5 complete (0/0/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200207114722_06530606_005_01.h5 (1 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200109131121_02110606_005_01.h5 complete (404779/1178/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200109131121_02110606_005_01.h5 (2 out of 6 resources)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20191213021930_11790502_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200111005531_02340602_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200111005531_02340602_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200111005531_02340602_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200115004711_02950602_005_01.h5)
# INFO:sliderule.sliderule:processing of ATL03_20191211143520_11560506_005_01.h5 complete (406546/1817/0|46/46/46/0)
# INFO:sliderule.icesat2:46 points returned for ATL03_20191211143520_11560506_005_01.h5 (3 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20191213021930_11790502_005_01.h5 complete (459064/1065/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20191213021930_11790502_005_01.h5 (4 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200111005531_02340602_005_01.h5 complete (0/0/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200111005531_02340602_005_01.h5 (5 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200115004711_02950602_005_01.h5 complete (460308/1169/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200115004711_02950602_005_01.h5 (6 out of 6 resources)
# /var/folders/0n/swn__wf94qd3zdch1tvp087r0000gn/T/ipykernel_45310/837220965.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(rsps)
# INFO:sliderule.icesat2:Identified 6 resources to process
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200109131121_02110606_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20191213021930_11790502_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200115004711_02950602_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200111005531_02340602_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200207114722_06530606_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20191211143520_11560506_005_01.h5 ...
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:processing of ATL03_20200207114722_06530606_005_01.h5 complete (0/0/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200207114722_06530606_005_01.h5 (1 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200109131121_02110606_005_01.h5 complete (404779/1178/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200109131121_02110606_005_01.h5 (2 out of 6 resources)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200111005531_02340602_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20191213021930_11790502_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200111005531_02340602_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200111005531_02340602_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200115004711_02950602_005_01.h5)
# INFO:sliderule.sliderule:processing of ATL03_20191211143520_11560506_005_01.h5 complete (406546/1585/0|278/269/287/0)
# INFO:sliderule.icesat2:287 points returned for ATL03_20191211143520_11560506_005_01.h5 (3 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20191213021930_11790502_005_01.h5 complete (459064/1065/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20191213021930_11790502_005_01.h5 (4 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200111005531_02340602_005_01.h5 complete (0/0/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200111005531_02340602_005_01.h5 (5 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200115004711_02950602_005_01.h5 complete (460308/1169/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200115004711_02950602_005_01.h5 (6 out of 6 resources)
# /var/folders/0n/swn__wf94qd3zdch1tvp087r0000gn/T/ipykernel_45310/837220965.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   res = res.append(rsps)
# INFO:sliderule.icesat2:Identified 6 resources to process
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20191211143520_11560506_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200109131121_02110606_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20191213021930_11790502_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200115004711_02950602_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200207114722_06530606_005_01.h5 ...
# INFO:sliderule.sliderule:atl06 processing initiated on ATL03_20200111005531_02340602_005_01.h5 ...
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_20200207114722_06530606_005_01.h5)
# INFO:sliderule.sliderule:processing of ATL03_20200207114722_06530606_005_01.h5 complete (0/0/0|0/0/0/0)
# INFO:sliderule.icesat2:0 points returned for ATL03_20200207114722_06530606_005_01.h5 (1 out of 6 resources)
# INFO:sliderule.sliderule:processing of ATL03_20200109131121_02110606_005_01.h5 complete (404779/830/0|348/132/564/0)
# INFO:sliderule.icesat2:564 points returned for ATL03_20200109131121_02110606_005_01.h5 (2 out of 6 resources)
# INFO:sliderule.sliderule:EMPTY_SUBSET exception <3>: empty spatial region (ATL03_
# time
# 2019-12-11 14:40:39.499674048        0.0            216  30      784416
# 2019-12-11 14:40:39.506722616        0.0            272  30      784419
# 2019-12-11 14:40:39.513786776        0.0            247  30      784421
# 2019-12-11 14:40:39.520849936        0.0            256  30      784424
# 2019-12-11 14:40:39.527914232        0.0            254  30      784427
# ...                                  ...            ...  ..         ...
# 2020-01-15 00:50:21.996410024        0.0            301  60      217112
# 2020-01-15 00:50:22.003404856        0.0            279  60      217114
# 2020-01-15 00:50:22.010390904        0.0            305  60      217117
# 2020-01-15 00:50:22.017398768        0.0            352  60      217119
# 2020-01-15 00:50:22.045698032        0.0            378  60      217129
#
#                                cycle      distance  rms_misfit   h_sigma  \
# time
# 2019-12-11 14:40:39.499674048      5  1.571132e+07    0.376011  0.027854
# 2019-12-11 14:40:39.506722616      5  1.571137e+07    0.285830  0.017332
# 2019-12-11 14:40:39.513786776      5  1.571142e+07    0.321257  0.020471
# 2019-12-11 14:40:39.520849936      5  1.571147e+07    0.258190  0.016152
# 2019-12-11 14:40:39.527914232      5  1.571152e+07    0.247505  0.015558
# ...                              ...           ...         ...       ...
# 2020-01-15 00:50:21.996410024      6  4.354042e+06    0.641254  0.036981
# 2020-01-15 00:50:22.003404856      6  4.354092e+06    0.806099  0.048575
# 2020-01-15 00:50:22.010390904      6  4.354142e+06    0.795507  0.047911
# 2020-01-15 00:50:22.017398768      6  4.354192e+06    1.143867  0.060969
# 2020-01-15 00:50:22.045698032      6  4.354393e+06    1.331539  0.068492
#
#                                                   geometry
# time
# 2019-12-11 14:40:39.499674048  POINT (-107.92571 39.17275)
# 2019-12-11 14:40:39.506722616  POINT (-107.92577 39.17231)
# 2019-12-11 14:40:39.513786776  POINT (-107.92582 39.17186)
# 2019-12-11 14:40:39.520849936  POINT (-107.92588 39.17141)
# 2019-12-11 14:40:39.527914232  POINT (-107.92593 39.17096)
# ...                                                    ...
# 2020-01-15 00:50:21.996410024  POINT (-108.27939 39.13802)
# 2020-01-15 00:50:22.003404856  POINT (-108.27945 39.13847)
# 2020-01-15 00:50:22.010390904  POINT (-108.27950 39.13892)
# 2020-01-15 00:50:22.017398768  POINT (-108.27956 39.13937)
# 2020-01-15 00:50:22.045698032  POINT (-108.27977 39.14117)
#
# [2138 rows x 16 columns]

# %%
for d in np.unique(rsps.index.date):
    day = rsps[rsps.index.date == d]
    later_days = rsps[rsps.index.date > d]
    for other_date in np.unique(later_days.index.date):
        other_day = later_days[later_days.index.date == other_date]
        # Now reproject to a crs using meters
        day = day.to_crs(epsg = 3857)
        other_day = other_day.to_crs(epsg = 3857)
        # intersect = day.overlay(other_days, how='intersection')
        # Buffer and join
        day['geometry'] = day['geometry'].buffer(200)
        # intersection = gpd.sjoin(day, other_days, how='left')
        intersection = day.overlay(other_day, how='intersection', keep_geom_type=False)
        intersection = intersection.to_crs(rsps.crs)
        intersection['h_delta'] = intersection['h_mean_1'] - intersection['h_mean_2']
        if intersection.size > 0:
            print(intersection.size)
            print(res.h_delta.mean())
            f, ax = plt.subplots()
            intersection.plot(column = 'h_delta', legend = True, ax = ax, vmin = -5, vmax = 5)
            gpd.read_file('grandmesa.geojson').plot(facecolor = "none", edgecolor = 'red', ax = ax)
            cx.add_basemap(ax, crs=intersection.crs.to_string())
            plt.show()
            res = intersection.copy()
