# %%
from uavsar_pytools.uavsar_tools import grd_tiff_convert

# %%
grd_tiff_convert('/Users/zachkeskinen/Downloads/grmesa_27416_20003-028_20017-006_0040d_s01_L090HH_01.unw.grd', ann_fp = '/Users/zachkeskinen/Downloads/grmesa_27416_20003-028_20017-006_0040d_s01_L090HH_01.ann.txt',out_dir='/Users/zachkeskinen/Downloads/')
# Out:
# ({'uavsar rpi annotation file version number': {'value': 2.3,
#    'units': '-',
#    'comment': 'uavsar rpi annotation file version number      (-)             = 2.3'},
#   'site description': {'value': 'Grand Mesa, CO',
#    'units': '&',
#    'comment': 'site description                               (&)             = grand mesa, co'},
#   'flight plan comments of pass 1': {'value': 'N/A',
#    'units': '&',
#    'comment': 'flight plan comments of pass 1                 (&)             = n/a'},
#   'flight plan comments of pass 2': {'value': 'N/A',
#    'units': '&',
#    'comment': 'flight plan comments of pass 2                 (&)             = n/a'},
#   'processing comments': {'value': 'N/A',
#    'units': '&',
#    'comment': 'processing comments                            (&)             = n/a'},
#   'url': {'value': 'http://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName',
#    'units': '&',
# ...
